# %%
age=21
price=100
name='imran'
print(type(name))
# Out:
# <class 'str'>

# %%
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
marke=(10,20,30,40,50)
print(marke.index(10))
marks1,marks2,marks3,marks4,marks5=marke
print(marks1,marks2,marks3)
# Out:
# 0
# 10 20 30

# %%
students={'name':'imran','age':21,'marks':100}
students["city"]="bangalore"
students["marks"]=90
print(students)
del students["age"]
print(students)
# Out:
# {'name': 'imran', 'age': 21, 'marks': 90, 'city': 'bangalore'}
# {'name': 'imran', 'marks': 90, 'city': 'bangalore'}
