# %%
name="ai assistant"
print("ai" in name)
# Out:
# True

# %%
for i in range(5):
    print("python_basic.py")
# Out:
# python_basic.py
# python_basic.py
# python_basic.py
# python_basic.py
# python_basic.py

# %%
print(chr(97))
# Out:
# a

# %%
str="artificial intelligence"
print(str[5:0:-1])
# Out:
# ifitr
